# %%
import matplotlib.pyplot as plt

# %%
x1=[1,4,6]
y1=[7,9,20]

# %%
plt.xlabel('ashu x-axis data')
plt.ylabel('ashu y-axis data')
plt.plot(x1,y1) # for line plot 
plt.bar(x1,y1)
plt.title('ashu graph plots')
plt.grid()
plt.show()
