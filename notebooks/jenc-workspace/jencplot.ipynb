# %%
import matplotlib.pyplot as plt

# %%
x1=[1,4,6]
y1=[7,9,20]

# %%
plt.xlabel('jenc x-axis data')
plt.ylabel('jenc y-axis data')
plt.plot(x1,y1) # for line plot
plt.bar(x1,y1)
plt.title('jenc graph plots')
plt.grid()
plt.show()
