# %%
import matplotlib.pyplot as plt

# %%
x1=[1,4,6]
y1=[2,6,9]

# %%
plt.xlabel('rocelia x-axis data')
plt.ylabel('ashu y-axis data')
plt.plot(x1,y1) # for line plot
plt.bar(x1,y1)
plt.title('rocelia graph plots')
plt.grid()
plt.show()
