# %%
# import the matplotlib
import matplotlib.pyplot as plt

# %%
x1=[1,4,6]
y1=[7,9,20]

# %%
plt.xlabel('barker x-axis data')
plt.ylabel('barker y-axis data')
# for th plot
plt.plot(x1,y1)
plt.bar(x1,y1)
plt.title('barker  graph plots')
plt.grid()
plt.show()
