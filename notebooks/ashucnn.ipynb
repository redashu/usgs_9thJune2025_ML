# %%
from tensorflow.keras.datasets import cifar10
import matplotlib.pyplot as plt

# %%
# loading data as training and testing part
(x_train,y_train),(x_test,y_test)=cifar10.load_data()

# %%
# 10 classe
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# lets try to access even single image 
# Show one image with label
# default image size in this dataset is 32x32
index = 0  # Change this to view a different image
plt.imshow(x_train[index])
plt.title(f"Label: {class_names[y_train[index][0]]}")
plt.axis('off')
plt.show()

# %%
# View first 9 images in a 3x3 grid
plt.figure(figsize=(8, 8))
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.imshow(x_train[i])
    plt.title(class_names[y_train[i][0]])
    plt.axis('off')
plt.tight_layout()
plt.show()
