# %%
import matplotlib.pyplot as plt

# %%
x1 = [1,4,6]
y1 = [2,9,20]

# %%
plt.xlabel('x axis data')
plt.ylabel(' y axis data')
plt.plot(x1,y1)
plt.bar(x1,y1)
plt.title('graph title')
plt.grid()
plt.show()
