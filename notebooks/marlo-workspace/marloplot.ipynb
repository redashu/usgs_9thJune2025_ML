# %%
import matplotlib.pyplot as plt

# %%
x1=[1,4,6]
y1=[7,9,20]

# %%
plt.xlabel('marlo x-axis data')
plt.ylabel('marlo y-axis data')
plt.plot(x1,y1)
plt.bar(x1,y1)
plt.title('marlo graph plots')
plt.grid()
plt.show()
