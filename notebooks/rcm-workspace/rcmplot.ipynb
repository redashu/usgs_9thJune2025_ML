# %%
import matplotlib.pyplot as plt

# %%
x1=[1,4,6]
y1=[7,9,20]

# %%
plt.xlabel('rcm x-axis data')
plt.ylabel('rcm y-axis data')
plt.plot(x1,y1) # for line plot
plt.bar(x1,y1) # for bar plot
plt.title('RCM Random Data Graph')
plt.grid()
plt.show()
